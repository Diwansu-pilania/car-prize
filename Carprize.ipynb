# %% [markdown]
# <a href="https://colab.research.google.com/github/Diwansu-pilania/car-prize/blob/main/Carprize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('/content/car_train.csv')

# %%
df
# Out:
#               model  year motor_type        running  ...   type     status motor_volume  price
# 0            toyota  2022     petrol       3000  km  ...  sedan  excellent          2.0  24500
# 1     mercedes-benz  2014     petrol     132000  km  ...  sedan  excellent          2.0  25500
# 2               kia  2018     petrol   95000  miles  ...  sedan  excellent          2.0  11700
# 3     mercedes-benz  2002     petrol  137000  miles  ...  sedan  excellent          3.2  12000
# 4     mercedes-benz  2017     petrol     130000  km  ...  sedan       good          2.0  26000
# ...             ...   ...        ...            ...  ...    ...        ...          ...    ...
# 1637        hyundai  2017     petrol  120000  miles  ...  sedan       good          2.0  12400
# 1638         toyota  2014     petrol     170000  km  ...  sedan       good          2.0  16500
# 1639         nissan  2018     petrol   68900  miles  ...    suv       good          2.0  19500
# ...

# %%
df['model'].unique()
# Out:
# array(['toyota', 'mercedes-benz', 'kia', 'nissan', 'hyundai'],
#       dtype=object)

# %%
df['model']=df['model'].map({'toyota':1, 'mercedes-benz':2, 'kia':3, 'nissan':4, 'hyundai':5})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1642 entries, 0 to 1641
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         1642 non-null   int64
#  1   year          1642 non-null   int64
#  2   motor_type    1642 non-null   object
#  3   running       1642 non-null   object
#  4   wheel         1642 non-null   object
#  5   color         1642 non-null   object
#  6   type          1642 non-null   object
#  7   status        1642 non-null   object
#  8   motor_volume  1642 non-null   float64
#  9   price         1642 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 128.4+ KB

# %%
df['wheel'].unique()
# Out:
# array(['left'], dtype=object)

# %%
df=df.drop('wheel',axis=1)

# %%
df['motor_type'].unique()
# Out:
# array(['petrol', 'gas', 'petrol and gas', 'diesel', 'hybrid'],
#       dtype=object)

# %%
df
# Out:
#       model  year motor_type        running    color   type     status  motor_volume  price
# 0         1  2022     petrol       3000  km  skyblue  sedan  excellent           2.0  24500
# 1         2  2014     petrol     132000  km    black  sedan  excellent           2.0  25500
# 2         3  2018     petrol   95000  miles    other  sedan  excellent           2.0  11700
# 3         2  2002     petrol  137000  miles   golden  sedan  excellent           3.2  12000
# 4         2  2017     petrol     130000  km    black  sedan       good           2.0  26000
# ...     ...   ...        ...            ...      ...    ...        ...           ...    ...
# 1637      5  2017     petrol  120000  miles    white  sedan       good           2.0  12400
# 1638      1  2014     petrol     170000  km    black  sedan       good           2.0  16500
# 1639      4  2018     petrol   68900  miles     blue    suv       good           2.0  19500
# ...

# %%
df = pd.get_dummies(df, columns=['motor_type'], prefix='motor')

# %%
df['motor_gas']=df['motor_gas'].astype(int)

# %%
df['motor_hybrid']=df['motor_hybrid'].astype(int)

# %%
df['motor_diesel']=df['motor_diesel'].astype(int)

# %%
df['motor_petrol']=df['motor_petrol'].astype(int)

# %%
df['motor_petrol and gas']=df['motor_petrol and gas'].astype(int)

# %%
df['running']=df['running'].str.split( ).str[0]

# %%
df
# Out:
#       model  year running    color  ... motor_gas motor_hybrid  motor_petrol  motor_petrol and gas
# 0         1  2022    3000  skyblue  ...         0            0             1                     0
# 1         2  2014  132000    black  ...         0            0             1                     0
# 2         3  2018   95000    other  ...         0            0             1                     0
# 3         2  2002  137000   golden  ...         0            0             1                     0
# 4         2  2017  130000    black  ...         0            0             1                     0
# ...     ...   ...     ...      ...  ...       ...          ...           ...                   ...
# 1637      5  2017  120000    white  ...         0            0             1                     0
# 1638      1  2014  170000    black  ...         0            0             1                     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1642 entries, 0 to 1641
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 1642 non-null   int64
#  1   year                  1642 non-null   int64
#  2   running               1642 non-null   object
#  3   color                 1642 non-null   object
#  4   type                  1642 non-null   object
#  5   status                1642 non-null   object
#  6   motor_volume          1642 non-null   float64
#  7   price                 1642 non-null   int64
#  8   motor_diesel          1642 non-null   bool
#  9   motor_gas             1642 non-null   int64
#  10  motor_hybrid          1642 non-null   int64
#  11  motor_petrol          1642 non-null   int64
#  12  motor_petrol and gas  1642 non-null   int64
# dtypes: bool(1), float64(1), int64(7), object(4)
# memory usage: 155.7+ KB

# %%
df['running']=df['running'].astype(int)

# %%
df['color'].unique()
# Out:
# array(['skyblue', 'black', 'other', 'golden', 'blue', 'gray', 'silver',
#        'white', 'clove', 'orange', 'red', 'green', 'cherry', 'brown',
#        'beige', 'purple', 'pink'], dtype=object)

# %%
df['color']=df['color'].map({'skyblue':1, 'black':2, 'other':3, 'golden':4, 'blue':5, 'gray':6, 'silver':7,
       'white':8, 'clove':9, 'orange':10, 'red':11, 'green':12, 'cherry':13, 'brown':14,
       'beige':15, 'purple':16, 'pink':17})

# %%
df['type'].unique()
# Out:
# array(['sedan', 'suv', 'Universal', 'Coupe', 'pickup', 'hatchback',
#        'minivan / minibus'], dtype=object)

# %%
df['type']=df['type'].map({'sedan':1, 'suv':2, 'Universal':3, 'Coupe':4, 'pickup':5, 'hatchback':6,
       'minivan / minibus':7})

# %%
df['status'].unique()
# Out:
# array(['excellent', 'good', 'crashed', 'normal', 'new'], dtype=object)

# %%
df['status']=df['status'].map({'excellent':4, 'good':3, 'crashed':1, 'normal':2, 'new':5})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1642 entries, 0 to 1641
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 1642 non-null   int64
#  1   year                  1642 non-null   int64
#  2   running               1642 non-null   int64
#  3   color                 1642 non-null   int64
#  4   type                  1642 non-null   int64
#  5   status                1642 non-null   int64
#  6   motor_volume          1642 non-null   float64
#  7   price                 1642 non-null   int64
#  8   motor_diesel          1642 non-null   int64
#  9   motor_gas             1642 non-null   int64
#  10  motor_hybrid          1642 non-null   int64
#  11  motor_petrol          1642 non-null   int64
#  12  motor_petrol and gas  1642 non-null   int64
# dtypes: float64(1), int64(12)
# memory usage: 166.9 KB

# %%
df
# Out:
#       model  year  running  color  ...  motor_gas  motor_hybrid  motor_petrol  motor_petrol and gas
# 0         1  2022     3000      1  ...          0             0             1                     0
# 1         2  2014   132000      2  ...          0             0             1                     0
# 2         3  2018    95000      3  ...          0             0             1                     0
# 3         2  2002   137000      4  ...          0             0             1                     0
# 4         2  2017   130000      2  ...          0             0             1                     0
# ...     ...   ...      ...    ...  ...        ...           ...           ...                   ...
# 1637      5  2017   120000      8  ...          0             0             1                     0
# 1638      1  2014   170000      2  ...          0             0             1                     0
# ...

# %%
y=df['price']

# %%
x=df.drop('price',axis=1)

# %%
x_tensor = torch.tensor(x.to_numpy(), dtype=torch.float32)
y_tensor = torch.tensor(y.to_numpy(), dtype=torch.float32).view(-1, 1)
df1_tensor = torch.tensor(df1.to_numpy(), dtype=torch.float32)

# %%
import torch.nn as nn

class RegressionModel(nn.Module):
    def __init__(self, input_size):
        super(RegressionModel, self).__init__()
        self.layer1 = nn.Linear(input_size, 128)
        self.layer2 = nn.Linear(128, 64)
        self.layer3 = nn.Linear(64, 32)
        self.output = nn.Linear(32, 1)

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.relu(self.layer2(x))
        x = torch.relu(self.layer3(x))
        return self.output(x)  # No activation in the last layer for regression

# Initialize the model
model = RegressionModel(input_size=.shape[1])

# %%
import torch.optim as optim

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 10
batch_size = 32

for epoch in range(epochs):
  model.train()
  for i in range(0 , len(x_tensor), batch_size):
    x_batch = x_tensor[i:i+batch_size]
    y_batch = y_tensor[i:i+batch_size]

    output = model(x_batch)
    loss = criterion(output, y_batch)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  if (epoch +1)%10 == 0:
    print(f"epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}")
# Out:
# epoch 10/10, Loss: 20002584.0000

# %%
with torch.no_grad():
  predictions = model(df1_tensor)

# %%
predictions
# Out:
# tensor([[20226.1484],
#         [17067.6484],
#         [19771.8516],
#         [18697.6523],
#         [ 9927.0137],
#         [20525.0859],
#         [10015.3945],
#         [14537.3828],
#         [13169.6123],
#         [18306.0000],
#         [17713.9805],
#         [ 8616.8623],
#         [17153.6895],
#         [17057.7188],
#         [15851.5898],
#         [14172.0654],
#         [17673.8574],
#         [18517.1328],
#         [17709.2559],
#         [16451.0312],
#         [ 9745.8027],
#         [ 8498.5811],
#         [12734.8086],
#         [20418.4219],
#         [18679.3047],
#         [19837.6523],
#         [20198.1406],
#         [18318.6309],
#         [18926.2207],
#         [19705.3906],
#         [20025.6523],
#         [16770.2578],
#         [18010.3789],
#         [ 9110.4199],
#         [20604.1289],
#         [18461.3203],
#         [ 8786.0771],
#         [18844.6133],
#         [19905.0625],
#         [17279.3711],
#         [19670.6543],
# ...

# %%
result=pd.DataFrame(predictions,columns=['price'])

# %%
result = pd.concat([result, id], axis=1)

# %%
result.to_csv('result.csv',index=False)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x,y)
# Out:
# RandomForestRegressor()

# %%
df1=pd.read_csv('/content/car_test.csv')

# %%
df
# Out:
#       model  year  running  color  ...  motor_gas  motor_hybrid  motor_petrol  motor_petrol and gas
# 0         1  2022     3000      1  ...          0             0             1                     0
# 1         2  2014   132000      2  ...          0             0             1                     0
# 2         3  2018    95000      3  ...          0             0             1                     0
# 3         2  2002   137000      4  ...          0             0             1                     0
# 4         2  2017   130000      2  ...          0             0             1                     0
# ...     ...   ...      ...    ...  ...        ...           ...           ...                   ...
# 1637      5  2017   120000      8  ...          0             0             1                     0
# 1638      1  2014   170000      2  ...          0             0             1                     0
# ...

# %%
new_order = ['model','year','running','color','type','status','motor_volume','motor_diesel','motor_gas','motor_hybrid','motor_petrol','motor_petrol and gas']

# %%
df1 =df1[new_order]

# %%
df1
# Out:
#      model  year  running  color  ...  motor_gas  motor_hybrid  motor_petrol  motor_petrol and gas
# 0        3  2020    24000      2  ...          0             0             1                     0
# 1        4  2017    85000      8  ...          0             0             1                     0
# 2        5  2021    30000      8  ...          0             0             1                     0
# 3        3  2018    53000      7  ...          0             0             1                     0
# 4        2  2003   230000      2  ...          0             0             1                     0
# ..     ...   ...      ...    ...  ...        ...           ...           ...                   ...
# 406      4  2021    33400      2  ...          0             0             1                     0
# 407      5  2017    60000      3  ...          0             0             1                     0
# ...

# %%
df1['model'] = df1['model'].map({'toyota': 1, 'mercedes-benz': 2, 'kia': 3, 'nissan': 4, 'hyundai': 5})

# Drop the 'wheel' column
df1 = df1.drop('wheel', axis=1)
df1 = pd.get_dummies(df1, columns=['motor_type'], prefix='motor')


# Process the 'running' column
df1['running'] = df1['running'].str.split().str[0]
df1['running'] = df1['running'].astype(int)

# Map the 'color' column
df1['color'] = df1['color'].map({'skyblue': 1, 'black': 2, 'other': 3, 'golden': 4, 'blue': 5, 'gray': 6,
                                  'silver': 7, 'white': 8, 'clove': 9, 'orange': 10, 'red': 11,
                                  'green': 12, 'cherry': 13, 'brown': 14, 'beige': 15,
                                  'purple': 16, 'pink': 17})

# Map the 'type' column
df1['type'] = df1['type'].map({'sedan': 1, 'suv': 2, 'Universal': 3, 'Coupe': 4, 'pickup': 5,
                                'hatchback': 6, 'minivan / minibus': 7})

# Map the 'status' column
df1['status'] = df1['status'].map({'excellent': 4, 'good': 3, 'crashed': 1, 'normal': 2, 'new': 5})

# %%
df1
# Out:
#       Id  model  year  running  ...  motor_volume  motor_gas  motor_petrol  motor_petrol and gas
# 0      0      3  2020    24000  ...           2.0      False          True                 False
# 1      1      4  2017    85000  ...           2.0      False          True                 False
# 2      2      5  2021    30000  ...           2.0      False          True                 False
# 3      3      3  2018    53000  ...           2.0      False          True                 False
# 4      4      2  2003   230000  ...           1.8      False          True                 False
# ..   ...    ...   ...      ...  ...           ...        ...           ...                   ...
# 406  406      4  2021    33400  ...           2.0      False          True                 False
# 407  407      5  2017    60000  ...           2.0      False          True                 False
# 408  408      2  2012   218000  ...           2.0      False          True                 False
# ...

# %%
df1['motor_gas']=df1['motor_gas'].astype(int)
df1['motor_petrol']=df1['motor_petrol'].astype(int)
df1['motor_petrol and gas']=df1['motor_petrol and gas'].astype(int)

# %%
id = df1['Id']

# %%
df1=df1.drop('Id',axis=1)

# %%
import pandas as pd

# Create a DataFrame for motor_diesel with 411 rows and all values set to 0
motor_diesel = pd.DataFrame({'motor_diesel': [0] * 411})

# Create a DataFrame for motor_hybrid with 411 rows and all values set to 0
motor_hybrid = pd.DataFrame({'motor_hybrid': [0] * 411})

# Display the DataFrames
print("motor_diesel DataFrame:")
print(motor_diesel)

print("\nmotor_hybrid DataFrame:")
print(motor_hybrid)
# Out:
# motor_diesel DataFrame:
#      motor_diesel
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 406             0
# 407             0
# 408             0
# 409             0
# 410             0
#
# [411 rows x 1 columns]
#
# motor_hybrid DataFrame:
#      motor_hybrid
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 406             0
# 407             0
# 408             0
# 409             0
# 410             0
#
# [411 rows x 1 columns]

# %%
df1=pd.concat([df1,motor_diesel],axis=1)

# %%
df1=pd.concat([df1,motor_hybrid],axis=1)

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df1 = df1[df.feature_names_in_]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-2b0325734cfa> in <cell line: 0>()
# ----> 1 df1 = df1[df.feature_names_in_]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'feature_names_in_'

# %%
y_pred=rf.predict(df1)

# %%
result=pd.DataFrame(y_pred,columns=['price'])

# %%
result
# Out:
#             price
# 0    17049.566667
# 1    16869.680000
# 2    25589.000000
# 3    14665.500000
# 4     5805.000000
# ..            ...
# 406  25599.120000
# 407  13965.000000
# 408  15087.000000
# 409  14851.740000
# 410  13509.000000
#
# [411 rows x 1 columns]

# %%
result = pd.concat([result, id], axis=1)

# %%
result.to_csv('result.csv',index=False)

# %%
# Out:
# diwansu-pilania
